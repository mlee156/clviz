# %%
import clarityviz as cl

# %%
cl.analysis.generate_scaled_centroids_graph('s3617_to_ara3', 's3617_to_ara3_regions.csv', output_path='output/s3617_to_ara3_centoids.html')
# Out:
# {6: [589.47169811320759, 465.62264150943395, 669.16981132075466, 53],
#  7: [503.57142857142856, 564.19047619047615, 1024.047619047619, 21],
#  9: [570.85714285714289, 121.71428571428571, 716.42857142857144, 7],
#  12: [584.0, 492.0, 876.0, 1],
#  14: [643.0, 461.0, 715.0, 1],
#  15: [550.39999999999998, 448.60000000000002, 583.20000000000005, 5],
#  17: [563.46000000000004, 233.81999999999999, 918.77999999999997, 50],
#  23: [485.77777777777777, 652.22222222222217, 584.88888888888891, 9],
#  26: [554.88, 238.19999999999999, 939.84000000000003, 25],
#  27: [649.66666666666663, 393.0, 779.0, 3],
#  33: [565.72413793103453, 159.13793103448276, 896.13793103448279, 29],
#  36: [670.0, 407.0, 389.33333333333331, 3],
#  41: [632.57142857142856, 51.428571428571431, 859.42857142857144, 7],
#  42: [555.4666666666667, 245.13333333333333, 941.5333333333333, 15],
#  50: [608.5, 322.0, 763.0, 2],
#  56: [562.39999999999998, 573.0625, 422.375, 80],
#  59: [565.5, 441.0, 723.0, 2],
# ...
